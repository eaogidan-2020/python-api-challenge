# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json




# Import API key
from api_keys import g_key
g_key = "AIzaSyBNMvWtqLEjrrAaV-lvOZpMuYgtjF975vI"

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities_df = pd.read_csv('../output_data/cities.csv', index_col = False)
cities_df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
import gmaps
gmaps.configure(api_key=g_key)

fig = gmaps.figure(map_type='HYBRID')
heatmap_layer = gmaps.heatmap_layer(df[["lat", "lon"]], weights=df["humidity"])
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
Address = ["Sheraton", "Landmark", "Ibis"]


address =  ['Hermanus', 'Mexicali', 'Hilo']
hotel_df = cities_df[(cities_df['Max Temp'] > 70) & (cities_df['Max Temp'] < 80)& (cities_df['Wind Speed'] < 10)& (cities_df['Cloudiness'] < 3)]


hotel_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 7          7         opuwo           0     NaN  1558378523        23 -18.06
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 87        87      ambilobe           2      MG  1558378770        92 -13.19
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
# 494      494         baylo           1      PH  1558378889        69   7.85
#
#         Lng  Max Temp  Wind Speed
# 7     13.84     72.06        5.44
# 70   -46.00     73.68        5.32
# 87    49.05     74.76        4.52
# 88   -50.22     76.56        5.50
# 138   44.28     79.08        9.06
# 139   74.49     78.90        1.59
# 176   -2.93     75.20        6.93
# 297   96.51     72.24        2.77
# 444   59.22     71.60        9.17
# 494  126.06     77.00        1.07

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
target_coordinates = ['-30.24, 15.30','30.50, -100.10','15.60,-112.12']
# target_search = "ZA"
target_radius = 5000
target_type = "hotels"


params = {
    "location": target_coordinates[1],
#     "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


response = requests.get(base_url, params=params)

# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 30.49082019999999,
#                     "lng": -100.0566754
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.5004347,
#                         "lng": -100.040668
#                     },
#                     "southwest": {
#                         "lat": 30.4812048,
#                         "lng": -100.0726828
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png",
#             "name": "Roosevelt",
#             "place_id": "ChIJEdVNXGz4WIYRyB-MrqItdHU",
#             "reference": "ChIJEdVNXGz4WIYRyB-MrqItdHU",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.49064119999999,
#                     "lng": -100.0562931
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4920688302915,
#                         "lng": -100.0549234697085
#                     },
#                     "southwest": {
#                         "lat": 30.4893708697085,
#                         "lng": -100.0576214302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/post_office-71.png",
#             "name": "United States Postal Service",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2835,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118038090586721073860\">Sara Neave</a>"
#                     ],
#                     "photo_reference": "ATtYBwJatqUIH0Zpue4mUMYPZS8ImYYnqpHKFqyI8Tvu8dsaMecdp-KH10kW87FZpVU6g8CRd4BjlUEEF1ubVyhW0qF7MIIJXsmPIyaY8wXVN1wy3BGyeEYphK4dA8TQwCyeUUVpfJgCjP3eccTy3XooleRPc2wZqZlumIAhB250LjJsSk32",
#                     "width": 2268
#                 }
#             ],
#             "place_id": "ChIJORaKkmz4WIYR-iZ7qGZgPb4",
#             "plus_code": {
#                 "compound_code": "FWRV+7F Roosevelt, TX, USA",
#                 "global_code": "852XFWRV+7F"
#             },
#             "rating": 5,
#             "reference": "ChIJORaKkmz4WIYR-iZ7qGZgPb4",
#             "scope": "GOOGLE",
#             "types": [
#                 "post_office",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "3861 Texas 291 Loop #291, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4986687,
#                     "lng": -100.0967675
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4999605302915,
#                         "lng": -100.0953899697085
#                     },
#                     "southwest": {
#                         "lat": 30.4972625697085,
#                         "lng": -100.0980879302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "Schwiening Ranch",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1377,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113233998200186272631\">Schwiening Ranch</a>"
#                     ],
#                     "photo_reference": "ATtYBwKmhXUUankIxOQ-lMtCJJtop28XXx7bSjrHYL0UxYpXcEDWqfHN24383krdgOHFv-XZ8XwPE_iSRZSmEd2C8M5y61RR86tA5wwctBRqMlaho_CziKKlGW-M5J4MdofD3mPPFIqnaHUUj4aBaT8mxPO3WBTF0VVebFqG5n5RdEruocMe",
#                     "width": 2448
#                 }
#             ],
#             "place_id": "ChIJ0e4yC_H3WIYRhlD-PJv8EQ8",
#             "plus_code": {
#                 "compound_code": "FWX3+F7 Roosevelt, TX, USA",
#                 "global_code": "852XFWX3+F7"
#             },
#             "rating": 5,
#             "reference": "ChIJ0e4yC_H3WIYRhlD-PJv8EQ8",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "2702 KC, #260, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.479132,
#                     "lng": -100.1020994
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4806255802915,
#                         "lng": -100.1007648197085
#                     },
#                     "southwest": {
#                         "lat": 30.4779276197085,
#                         "lng": -100.1034627802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "KJO OutFitters",
#             "place_id": "ChIJ250uRJX3WIYRq6FFSPGLgCQ",
#             "plus_code": {
#                 "compound_code": "FVHX+M5 Roosevelt, TX, USA",
#                 "global_code": "852XFVHX+M5"
#             },
#             "rating": 5,
#             "reference": "ChIJ250uRJX3WIYRq6FFSPGLgCQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4918501,
#                     "lng": -100.0739053
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4932479802915,
#                         "lng": -100.0725549697085
#                     },
#                     "southwest": {
#                         "lat": 30.4905500197085,
#                         "lng": -100.0752529302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png",
#             "name": "Camp Collier",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110302076364798682025\">H.C. Collier</a>"
#                     ],
#                     "photo_reference": "ATtYBwLPbkra3SWj1Hy8Qo2Kdb4okMSKaojseciZg6Qrpu0gy-5UD23dDnOkUgUYOk8yJ64xNYJG10mVfrqlpG9l9TXj2UaXL59_Jt2ruAAQ15JpKesPGtKWygaaEx4mFlkrWrgM7hmPYIVv5l5fAkm_vAe2HpXXfvtVIIxas40GBA1pVNjP",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJDRGAbBv4WIYRFwhtxsD76bQ",
#             "plus_code": {
#                 "compound_code": "FWRG+PC Roosevelt, TX, USA",
#                 "global_code": "852XFWRG+PC"
#             },
#             "reference": "ChIJDRGAbBv4WIYRFwhtxsD76bQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "museum",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "1105 Kc 260, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4791161,
#                     "lng": -100.081237
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4805605802915,
#                         "lng": -100.0799325197085
#                     },
#                     "southwest": {
#                         "lat": 30.4778626197085,
#                         "lng": -100.0826304802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "South Llano Farm",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106480692447915793408\">Andres Sarmiento</a>"
#                     ],
#                     "photo_reference": "ATtYBwLZjuY_DCPoQpdwnhIZ_ebTr3nFsqtcGWvQ_huYks3_-0IsYFk9f_aMkTxAIa74iPPmbt5n1yAiM0VZbW-NcNyYR4Mgwuhzm2UuJn7b2qxXJdNFQPDGa2iTCaQUXmWCNGyf_Y4eCIe2l9LgC3GqFqjv1Vodv2tWIwLkGVbD7stG6r-7",
#                     "width": 2268
#                 }
#             ],
#             "place_id": "ChIJx-I-4or3WIYR6A-gQp3yHdk",
#             "plus_code": {
#                 "compound_code": "FWH9+JG Junction, TX, USA",
#                 "global_code": "852XFWH9+JG"
#             },
#             "rating": 4,
#             "reference": "ChIJx-I-4or3WIYR6A-gQp3yHdk",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "550 Old Highway 290, Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4815578,
#                     "lng": -100.0654449
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4827233802915,
#                         "lng": -100.0646778697085
#                     },
#                     "southwest": {
#                         "lat": 30.4800254197085,
#                         "lng": -100.0673758302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#             "name": "State of Texas-Dot",
#             "photos": [
#                 {
#                     "height": 1932,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101378603102100199705\">TAUNA MELLOR</a>"
#                     ],
#                     "photo_reference": "ATtYBwJFE1CawoxF39-jx-bEuSvlDpwHxubcRl6Zk5-LzE7SgP2XtdLYgQ41M2rql6DcOVIqw7ZRQdIaXzFTpOmk6PqKhhlzsn6ZnSgI1zjpCZsoRea78pKy51OxMsaj8pzqxVCOwmSGiqxSpNDqtg1-f1IIM2SjdyS8_Am965b6LDKjYCX2",
#                     "width": 2576
#                 }
#             ],
#             "place_id": "ChIJ14iPSJANWYYRYh1rOycGSVk",
#             "plus_code": {
#                 "compound_code": "FWJM+JR Junction, TX, USA",
#                 "global_code": "852XFWJM+JR"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ14iPSJANWYYRYh1rOycGSVk",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "5145 E Ih 10, Junction"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4831025,
#                     "lng": -100.1365513
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.48413555,
#                         "lng": -100.1355402197085
#                     },
#                     "southwest": {
#                         "lat": 30.48000335,
#                         "lng": -100.1382381802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Comanche Moon Lodge",
#             "place_id": "ChIJOSxpHzz2WIYRpMzmQ1DEL2U",
#             "plus_code": {
#                 "compound_code": "FVM7+69 Roosevelt, TX, USA",
#                 "global_code": "852XFVM7+69"
#             },
#             "reference": "ChIJOSxpHzz2WIYRpMzmQ1DEL2U",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "4840 Co. Rd. 307 Sonora,, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4906394,
#                     "lng": -100.0562777
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4920652802915,
#                         "lng": -100.0549034197085
#                     },
#                     "southwest": {
#                         "lat": 30.4893673197085,
#                         "lng": -100.0576013802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Lyssy & Eckel - Roosevelt / Simon Brothers",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100757849789114662425\">bobby c</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ3MtXa9GZgrR4Tf8y4Woq8tBdF4FLfNbvy4OOL-Ch_38u2HIDbc75hlUFNECrlsJg5MmAKjCkSLopTxWjyOxQVz4MRH3kC4v0CnEzvENKBTasHAjg3QYKls558zQJnhZ4HSw9L5hD27RMdHMto8HiVoYLPqQdzxp0KHEMVr9-TT_ef",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJUYKYkmz4WIYRk6dYL9ce4Cg",
#             "plus_code": {
#                 "compound_code": "FWRV+7F Roosevelt, TX, USA",
#                 "global_code": "852XFWRV+7F"
#             },
#             "rating": 4.9,
#             "reference": "ChIJUYKYkmz4WIYRk6dYL9ce4Cg",
#             "scope": "GOOGLE",
#             "types": [
#                 "gas_station",
#                 "convenience_store",
#                 "cafe",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 31,
#             "vicinity": "3861 State Loop 291, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4899677,
#                     "lng": -100.0582852
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4913797302915,
#                         "lng": -100.0570051197085
#                     },
#                     "southwest": {
#                         "lat": 30.4886817697085,
#                         "lng": -100.0597030802915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Diamond J Processing & Fabrication",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117367588054292819945\">Christy Joy</a>"
#                     ],
#                     "photo_reference": "ATtYBwKVqkIeRx1yfZDdQgzMEM3xKffh3wyoCoTYfV6s5lApX8nDDR-0uFehq4NlozFt0PFl-FaJK7y-hDFYfFPr1VZADLPke31TPSiaK1RxJh5xtE6eB2_VA3m_8CcfooQkZX7Xrf00zJaDSYl4TUh7nPGT7l5BVAJ7IWDPGyV-rBOsaGZ4",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJr7OEccr5WIYRr5vhre9lvJE",
#             "plus_code": {
#                 "compound_code": "FWQR+XM Roosevelt, TX, USA",
#                 "global_code": "852XFWQR+XM"
#             },
#             "rating": 5,
#             "reference": "ChIJr7OEccr5WIYRr5vhre9lvJE",
#             "scope": "GOOGLE",
#             "types": [
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "4019 West, State Loop 291, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.4907941,
#                     "lng": -100.0562306
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4921127802915,
#                         "lng": -100.0548915697085
#                     },
#                     "southwest": {
#                         "lat": 30.4894148197085,
#                         "lng": -100.0575895302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png",
#             "name": "Back Door Cafe",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104028340078559892435\">Fabiola Barajas</a>"
#                     ],
#                     "photo_reference": "ATtYBwJTD5DbABgi9QCw1-2XQo-9nQYql-1UVLQbm3lSwCeBCAa3kIuIl9YGl8IGxCZm1mzJeZi8nCbhrm_7vORR9u0mdcsQtq9yk-7fL8VhONGMaRE_GoZakLpWugbS6YDneBbXbtK1jl6KVKtP-VD8z-0owidu5twdy5y1wuGjsEazW3SS",
#                     "width": 1960
#                 }
#             ],
#             "place_id": "ChIJtQFbxP_5WIYRVnwnvObhSEA",
#             "plus_code": {
#                 "compound_code": "FWRV+8G Roosevelt, TX, USA",
#                 "global_code": "852XFWRV+8G"
#             },
#             "price_level": 1,
#             "rating": 4.5,
#             "reference": "ChIJtQFbxP_5WIYRVnwnvObhSEA",
#             "scope": "GOOGLE",
#             "types": [
#                 "cafe",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "3879 West, Texas 291 Loop #291, Roosevelt"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.46787689999999,
#                     "lng": -100.1358816
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.46896173029149,
#                         "lng": -100.1346081697085
#                     },
#                     "southwest": {
#                         "lat": 30.46626376970849,
#                         "lng": -100.1373061302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#             "name": "Hill Country Hunting Adventures, LLC.",
#             "photos": [
#                 {
#                     "height": 762,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108583621280780542916\">Hill Country Hunting Adventures, LLC.</a>"
#                     ],
#                     "photo_reference": "ATtYBwJLgsA4KCUzNZ6qlG_HAV7j7ZXJ3YJFUg_nXqYDdwzsQ7Ev_OZbjU5uxMsc1lT4N16PPLbi0q9JqAke4kaVEwcg_HD6YMDAQMMx-v0uybrZCwryGFV_w-9RQpclk__8KKubBcUhBLOJphvPgqhxOjML-ya31A6Wvg3iDjqEs-plfLPO",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJe-8WM-T3WIYRddn2ssXpR2U",
#             "plus_code": {
#                 "compound_code": "FV97+5J Roosevelt, TX, USA",
#                 "global_code": "852XFV97+5J"
#             },
#             "reference": "ChIJe-8WM-T3WIYRddn2ssXpR2U",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "vicinity": "1069 Sutton County Road #310, Roosevelt"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 30.4939248,
#                     "lng": -100.1079314
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.4952143802915,
#                         "lng": -100.1065482697085
#                     },
#                     "southwest": {
#                         "lat": 30.4925164197085,
#                         "lng": -100.1092462302915
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cemetery_grave-71.png",
#             "name": "Cedar Hill Cemetery",
#             "place_id": "ChIJiXObYtz3WIYR0v5E6TwFovw",
#             "reference": "ChIJiXObYtz3WIYR0v5E6TwFovw",
#             "scope": "GOOGLE",
#             "types": [
#                 "cemetery",
#                 "premise",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "vicinity": "Roosevelt"
#         }
#     ],
#     "status": "OK"
# }

# %%
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Roosevelt
# Roosevelt

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-8345d215851b> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#      15
#
# NameError: name 'narrowed_city_df' is not defined

# %%
# Add marker layer ontop of heat map


# Display figure
